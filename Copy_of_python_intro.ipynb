# %% [markdown]
# <a href="https://colab.research.google.com/github/emekaokereke212-blip/AI-Portfolio-/blob/main/Copy_of_python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, AI World!")
# Out:
# Hello, AI World!
